# %% [markdown]
# # Linear Regression Example

# %% [markdown]
# Imports:

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path

sys.path.append(str(Path().resolve().parent))

from models.LinearRegression import LinearRegression
from Trainer import Trainer
from optimizers.SGDOptimizer import SGDOptimizer
from loss.LSELoss import LSELoss

# %% [markdown]
# Generate some data: (You may want to use custom data here)

# %%
x = np.linspace(0, 1, 10)
X = np.reshape(x, (x.shape[0], 1)) # for use in our model
y = x + np.random.rand()
x, y
# Out:
# (array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#         0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ]),
#  array([0.77222315, 0.88333426, 0.99444537, 1.10555648, 1.21666759,
#         1.3277787 , 1.43888981, 1.55000092, 1.66111204, 1.77222315]))

# %% [markdown]
# Initialize our model, loss, optimizer:

# %%
model = LinearRegression(1, 1)
optimizer = SGDOptimizer(0.05)
loss = LSELoss()

trainer = Trainer(model, loss, optimizer)

# %% [markdown]
# Plot our data and line before training:

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'o')
y_pred = trainer.model(X)
ax.plot(x, y_pred)
plt.show()

# %% [markdown]
# Train our model and plot results:

# %%
trainer.train(X, y, 20)
# Out:
# Epoch: 1
# Loss: 3.83572271096842
# Epoch: 2
# Loss: 0.29905938249851366
# Epoch: 3
# Loss: 0.03543067872754365
# Epoch: 4
# Loss: 0.01390841514596899
# Epoch: 5
# Loss: 0.010582660026934131
# Epoch: 6
# Loss: 0.008867787445785811
# Epoch: 7
# Loss: 0.00749779970066344
# Epoch: 8
# Loss: 0.006344458962580787
# Epoch: 9
# Loss: 0.00536889897159064
# Epoch: 10
# Loss: 0.004543373900839294
# Epoch: 11
# Loss: 0.003844784066659611
# Epoch: 12
# Loss: 0.00325360965617963
# Epoch: 13
# Loss: 0.00275333429745582
# Epoch: 14
# Loss: 0.0023299813306705223
# Epoch: 15
# Loss: 0.001971723159971769
# Epoch: 16
# Loss: 0.0016685508027056138
# Epoch: 17
# Loss: 0.0014119942584891263
# Epoch: 18
# Loss: 0.0011948858750799743
# Epoch: 19
# Loss: 0.001011160099187229
# Epoch: 20
# Loss: 0.000855684017622085

# %% [markdown]
# Plot the trained model:

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'o')
y_pred = trainer.model(X)
ax.plot(x, y_pred)
plt.show()

# %% [markdown]
# As you can see our modeled learned to fit the data
