# %% [markdown]
# # Linear Regression Example

# %% [markdown]
# Imports:

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path

sys.path.append(str(Path().resolve().parent))

from models.LinearRegression import LinearRegression
from GLMTrainer import GLMTrainer
from optimizers.SGDOptimizer import SGDOptimizer
from loss.LSELoss import LSELoss

# %% [markdown]
# Generate some data: (You may want to use custom data here)

# %%
x = np.linspace(0, 1, 10)
X = np.reshape(x, (x.shape[0], 1)) # for use in our model
y = x + np.random.rand()
x, y
# Out:
# (array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#         0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ]),
#  array([0.93340803, 1.04451914, 1.15563025, 1.26674136, 1.37785247,
#         1.48896359, 1.6000747 , 1.71118581, 1.82229692, 1.93340803]))

# %% [markdown]
# Initialize our model, loss, optimizer:

# %%
model = LinearRegression(1, 1)
optimizer = SGDOptimizer(0.05)
loss = LSELoss()

trainer = GLMTrainer(model, loss, optimizer)

# %% [markdown]
# Plot our data and line before training:

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'o')
y_pred = trainer.model(X)
ax.plot(x, y_pred)
plt.show()

# %% [markdown]
# Train our model and plot results:

# %%
trainer.train(X, y, 20)
# Out:
# Epoch: 1
# Loss: 1.703872402689464
# Epoch: 2
# Loss: 0.17586096002920965
# Epoch: 3
# Loss: 0.05531694457071814
# Epoch: 4
# Loss: 0.03990559064400317
# Epoch: 5
# Loss: 0.0332596661693578
# Epoch: 6
# Loss: 0.028107987118490167
# Epoch: 7
# Loss: 0.023783317997100026
# Epoch: 8
# Loss: 0.020126187082947368
# Epoch: 9
# Loss: 0.017031567297179792
# Epoch: 10
# Loss: 0.014412790624988417
# Epoch: 11
# Loss: 0.012196678363145745
# Epoch: 12
# Loss: 0.010321315828846307
# Epoch: 13
# Loss: 0.008734309237692495
# Epoch: 14
# Loss: 0.007391320944760555
# Epoch: 15
# Loss: 0.006254830670858391
# Epoch: 16
# Loss: 0.0052930872591668374
# Epoch: 17
# Loss: 0.004479221614053727
# Epoch: 18
# Loss: 0.00379049603481585
# Epoch: 19
# Loss: 0.003207668971964896
# Epoch: 20
# Loss: 0.0027144574586545483

# %% [markdown]
# Plot the trained model:

# %%
fig, ax = plt.subplots()

ax.plot(x, y, 'o')
y_pred = trainer.model(X)
ax.plot(x, y_pred)
plt.show()

# %% [markdown]
# As you can see our modeled learned to fit the data
